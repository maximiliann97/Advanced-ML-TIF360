# %% [markdown]
# # Warm up
# ### 1abc)

# %%
from torch_geometric.datasets import Planetoid
from torch_geometric.transforms import NormalizeFeatures

# %%
# Helper function for visualization.
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def visualize(h, color):
    z = TSNE(n_components=2).fit_transform(h.detach().cpu().numpy())

    plt.figure(figsize=(10,10))
    plt.xticks([])
    plt.yticks([])

    plt.scatter(z[:, 0], z[:, 1], s=70, c=color, cmap="Set2")
    plt.show()

# %%
dataset = Planetoid(root='data/Planetoid', name='Cora', transform=NormalizeFeatures())

print()
print(f'Dataset: {dataset}:')
print('======================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')

data = dataset[0]  # Get the first graph object.

print()
print(data)
print('===========================================================================================================')

# Gather some statistics about the graph.
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
print(f'Number of training nodes: {data.train_mask.sum()}')
print(f'Training node label rate: {int(data.train_mask.sum()) / data.num_nodes:.2f}')
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Dataset: Cora():
# ======================
# Number of graphs: 1
# Number of features: 1433
# Number of classes: 7
#
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708])
# ===========================================================================================================
# Number of nodes: 2708
# Number of edges: 10556
# Average node degree: 3.90
# Number of training nodes: 140
# Training node label rate: 0.05
# Has isolated nodes: False
# Has self-loops: False
# Is undirected: True
# Processing...
# Done!

# %%
import torch
from torch.nn import Linear
from torch.nn import Dropout
import torch.nn.functional as F


class MLP(torch.nn.Module):
    '''
    input_features: features of dataset
    output_dim: classes of dataset
    width: How many hidden neurons in each layer
    '''
    def __init__(self,
                 input_features,
                 width, output_dim):
        super().__init__()
        self.fc_1 = Linear(input_features, width)
        self.fc_2 = Linear(width, width)
        self.drop = Dropout(p=0.5)
        self.fc_3 = Linear(width, output_dim)
        
    def forward(self, x):
        x = x.flatten(1, -1)
        x = self.fc_1(x)
        x = torch.relu(x)
        x = self.fc_2(x)
        x = torch.relu(x)
        x = self.drop(x)
        x = self.fc_3(x)
        return x

input_features = dataset.num_node_features
width = int(2*dataset.num_node_features/3)
output_dim = dataset.num_classes
model = MLP(input_features, width, output_dim)
print(model)
# Out:
# 955
# MLP(
#   (fc_1): Linear(in_features=1433, out_features=955, bias=True)
#   (fc_2): Linear(in_features=955, out_features=955, bias=True)
#   (drop): Dropout(p=0.5, inplace=False)
#   (fc_3): Linear(in_features=955, out_features=7, bias=True)
# )

# %%
criterion = torch.nn.CrossEntropyLoss()  # Define loss criterion.
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)  # Define optimizer.

best_test_acc = 0.0
num_epochs_without_improvement = 0
patience = 30  # Number of epochs to wait before stopping if there is no improvement.
for epoch in range(1, 301):
    model.train()
    optimizer.zero_grad()  # Clear gradients.
    out = model(data.x)  # Perform a single forward pass.
    loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
    loss.backward()  # Derive gradients.
    optimizer.step()  # Update parameters based on gradients.
    
    model.eval()
    with torch.no_grad():
        out = model(data.x)
        pred = out.argmax(dim=1)  # Use the class with highest probability.
        val_correct = pred[data.val_mask] == data.y[data.val_mask]  # Check against ground-truth labels.
        val_acc = int(val_correct.sum()) / int(data.val_mask.sum())  # Derive ratio of correct predictions.
        
    if val_acc > best_test_acc:
        best_test_acc = val_acc
        num_epochs_without_improvement = 0
    else:
        num_epochs_without_improvement += 1
    
    if num_epochs_without_improvement >= patience:
        print(f'Early stopping after {epoch} epochs. Best validation accuracy: {best_test_acc:.4f}')
        best_model_params_dense = model.state_dict()
        break
    
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Validation Accuracy: {val_acc:.4f}')
    
model.eval()
with torch.no_grad():
    out = model(data.x)
    pred = out.argmax(dim=1)  # Use the class with highest probability.
    test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
    test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
    
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# Epoch: 001, Loss: 1.9468, Validation Accuracy: 0.1140
# Epoch: 002, Loss: 1.9422, Validation Accuracy: 0.2280
# Epoch: 003, Loss: 1.9300, Validation Accuracy: 0.3520
# Epoch: 004, Loss: 1.8788, Validation Accuracy: 0.3260
# Epoch: 005, Loss: 1.7675, Validation Accuracy: 0.4500
# Epoch: 006, Loss: 1.5430, Validation Accuracy: 0.4220
# Epoch: 007, Loss: 1.1331, Validation Accuracy: 0.4740
# Epoch: 008, Loss: 0.6872, Validation Accuracy: 0.4660
# Epoch: 009, Loss: 0.2794, Validation Accuracy: 0.5420
# Epoch: 010, Loss: 0.0970, Validation Accuracy: 0.4980
# Epoch: 011, Loss: 0.0398, Validation Accuracy: 0.5080
# Epoch: 012, Loss: 0.0053, Validation Accuracy: 0.4960
# Epoch: 013, Loss: 0.0038, Validation Accuracy: 0.4560
# Epoch: 014, Loss: 0.0040, Validation Accuracy: 0.4300
# Epoch: 015, Loss: 0.0016, Validation Accuracy: 0.4300
# Epoch: 016, Loss: 0.0020, Validation Accuracy: 0.4340
# Epoch: 017, Loss: 0.0013, Validation Accuracy: 0.4540
# Epoch: 018, Loss: 0.0036, Validation Accuracy: 0.4880
# Epoch: 019, Loss: 0.0022, Validation Accuracy: 0.5420
# Epoch: 020, Loss: 0.0039, Validation Accuracy: 0.5820
# Epoch: 021, Loss: 0.0160, Validation Accuracy: 0.5860
# Epoch: 022, Loss: 0.0235, Validation Accuracy: 0.5940
# Epoch: 023, Loss: 0.0265, Validation Accuracy: 0.4700
# Epoch: 024, Loss: 0.0438, Validation Accuracy: 0.5540
# Epoch: 025, Loss: 0.0737, Validation Accuracy: 0.4600
# Epoch: 026, Loss: 0.0832, Validation Accuracy: 0.5480
# Epoch: 027, Loss: 0.0736, Validation Accuracy: 0.4940
# Epoch: 028, Loss: 0.0677, Validation Accuracy: 0.4880
# Epoch: 029, Loss: 0.0281, Validation Accuracy: 0.4920
# Epoch: 030, Loss: 0.0290, Validation Accuracy: 0.4940
# Epoch: 031, Loss: 0.0306, Validation Accuracy: 0.5460
# Epoch: 032, Loss: 0.0218, Validation Accuracy: 0.5500
# Epoch: 033, Loss: 0.0124, Validation Accuracy: 0.5300
# Epoch: 034, Loss: 0.0220, Validation Accuracy: 0.5120
# Epoch: 035, Loss: 0.0122, Validation Accuracy: 0.5160
# Epoch: 036, Loss: 0.0133, Validation Accuracy: 0.5320
# Epoch: 037, Loss: 0.0124, Validation Accuracy: 0.5540
# Epoch: 038, Loss: 0.0111, Validation Accuracy: 0.5740
# Epoch: 039, Loss: 0.0128, Validation Accuracy: 0.5780
# Epoch: 040, Loss: 0.0164, Validation Accuracy: 0.5760
# Epoch: 041, Loss: 0.0101, Validation Accuracy: 0.5500
# Epoch: 042, Loss: 0.0135, Validation Accuracy: 0.5420
# Epoch: 043, Loss: 0.0183, Validation Accuracy: 0.5300
# Epoch: 044, Loss: 0.0193, Validation Accuracy: 0.5420
# Epoch: 045, Loss: 0.0166, Validation Accuracy: 0.5520
# Epoch: 046, Loss: 0.0215, Validation Accuracy: 0.5520
# Epoch: 047, Loss: 0.0281, Validation Accuracy: 0.5640
# Epoch: 048, Loss: 0.0262, Validation Accuracy: 0.5660
# Epoch: 049, Loss: 0.0332, Validation Accuracy: 0.5720
# Epoch: 050, Loss: 0.0286, Validation Accuracy: 0.5560
# Epoch: 051, Loss: 0.0340, Validation Accuracy: 0.5540
# Early stopping after 52 epochs. Best validation accuracy: 0.5940
# Test Accuracy: 0.5870

# %%
model = MLP(input_features, width, output_dim)
model.load_state_dict(best_model_params_dense)
out = model(data.x)
visualize(out, color=data.y)

# %%
from torch_geometric.nn import GCNConv

class GCN(torch.nn.Module):
    '''
    input_features: features of dataset
    output_dim: classes of dataset
    width: How many hidden neurons in each layer
    '''
    def __init__(self,
                 input_features,
                 width, output_dim):
        super().__init__()
        self.conv1 = GCNConv(input_features, width)
        self.dropout = Dropout(p=0.5)
        self.conv2 = GCNConv(width, output_dim)

    def forward(self, x, edge_index):
      x = self.conv1(x, edge_index)
      x = torch.relu(x)
      x = self.dropout(x)
      x = self.conv2(x, edge_index)

      return x

# %%
# Model
input_features = dataset.num_node_features
width = int(2*dataset.num_node_features/3)
output_dim = dataset.num_classes
model = GCN(input_features, width, output_dim)


# Optimizer
lr = 0.01
weight_decay = 5e-4
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
criterion = torch.nn.CrossEntropyLoss()


best_test_acc = 0.0
num_epochs_without_improvement = 0
patience = 60  # Number of epochs to wait before stopping if there is no improvement.
for epoch in range(1, 301):
    model.train()
    optimizer.zero_grad()  # Clear gradients.
    out = model(data.x, data.edge_index)  # Perform a single forward pass.
    loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
    loss.backward()  # Derive gradients.
    optimizer.step()  # Update parameters based on gradients.
    
    model.eval()
    with torch.no_grad():
        out = model(data.x, data.edge_index)
        pred = out.argmax(dim=1)  # Use the class with highest probability.
        val_correct = pred[data.val_mask] == data.y[data.val_mask]  # Check against ground-truth labels.
        val_acc = int(val_correct.sum()) / int(data.val_mask.sum())  # Derive ratio of correct predictions.
        
    if val_acc > best_test_acc:
        best_test_acc = val_acc
        num_epochs_without_improvement = 0
    else:
        num_epochs_without_improvement += 1
    
    if num_epochs_without_improvement >= patience:
        print(f'Early stopping after {epoch} epochs. Best validation accuracy: {best_test_acc:.4f}')
        best_model_params_dense = model.state_dict()
        break
    
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Validation Accuracy: {val_acc:.4f}')
    
model.eval()
with torch.no_grad():
    out = model(data.x, data.edge_index)
    pred = out.argmax(dim=1)  # Use the class with highest probability.
    test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
    test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
    
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# Epoch: 001, Loss: 1.9462, Validation Accuracy: 0.3540
# Epoch: 002, Loss: 1.9085, Validation Accuracy: 0.2780
# Epoch: 003, Loss: 1.8605, Validation Accuracy: 0.4220
# Epoch: 004, Loss: 1.7933, Validation Accuracy: 0.6000
# Epoch: 005, Loss: 1.7087, Validation Accuracy: 0.6880
# Epoch: 006, Loss: 1.6176, Validation Accuracy: 0.7500
# Epoch: 007, Loss: 1.5049, Validation Accuracy: 0.7700
# Epoch: 008, Loss: 1.3770, Validation Accuracy: 0.7780
# Epoch: 009, Loss: 1.2468, Validation Accuracy: 0.7800
# Epoch: 010, Loss: 1.1185, Validation Accuracy: 0.7880
# Epoch: 011, Loss: 0.9783, Validation Accuracy: 0.7920
# Epoch: 012, Loss: 0.8663, Validation Accuracy: 0.7900
# Epoch: 013, Loss: 0.7518, Validation Accuracy: 0.7960
# Epoch: 014, Loss: 0.6610, Validation Accuracy: 0.8040
# Epoch: 015, Loss: 0.5754, Validation Accuracy: 0.8040
# Epoch: 016, Loss: 0.4873, Validation Accuracy: 0.8000
# Epoch: 017, Loss: 0.4383, Validation Accuracy: 0.7920
# Epoch: 018, Loss: 0.3906, Validation Accuracy: 0.7960
# Epoch: 019, Loss: 0.3644, Validation Accuracy: 0.8060
# Epoch: 020, Loss: 0.3202, Validation Accuracy: 0.8000
# Epoch: 021, Loss: 0.2977, Validation Accuracy: 0.8000
# Epoch: 022, Loss: 0.2813, Validation Accuracy: 0.7900
# Epoch: 023, Loss: 0.2756, Validation Accuracy: 0.7900
# Epoch: 024, Loss: 0.2551, Validation Accuracy: 0.7880
# Epoch: 025, Loss: 0.2480, Validation Accuracy: 0.7880
# Epoch: 026, Loss: 0.2407, Validation Accuracy: 0.7940
# Epoch: 027, Loss: 0.2388, Validation Accuracy: 0.7880
# Epoch: 028, Loss: 0.2306, Validation Accuracy: 0.7860
# Epoch: 029, Loss: 0.2280, Validation Accuracy: 0.7940
# Epoch: 030, Loss: 0.2235, Validation Accuracy: 0.7920
# Epoch: 031, Loss: 0.2258, Validation Accuracy: 0.7960
# Epoch: 032, Loss: 0.2089, Validation Accuracy: 0.7920
# Epoch: 033, Loss: 0.2005, Validation Accuracy: 0.7860
# Epoch: 034, Loss: 0.2075, Validation Accuracy: 0.7940
# Epoch: 122, Loss: 0.1200, Validation Accuracy: 0.7940
# Epoch: 123, Loss: 0.1242, Validation Accuracy: 0.7900
# Epoch: 124, Loss: 0.1251, Validation Accuracy: 0.7900
# Epoch: 125, Loss: 0.1234, Validation Accuracy: 0.7900
# Epoch: 126, Loss: 0.1231, Validation Accuracy: 0.7880
# Early stopping after 127 epochs. Best validation accuracy: 0.8100
# Test Accuracy: 0.8120

# %%
model.eval()

out = model(data.x, data.edge_index)
visualize(out, color=data.y)

# %% [markdown]
# # Decoding a quantum memory
# ### The task will be to train a network for graph classification.
# - Design a graph neural network with the objective to optimize the accuracy on the
# test set. You should be able to get a test accuracy of at least 95%, possibly up to
# 98%.
# - Plot training and test accuracy over at least 10 epochs of training.
# - Be ready to discuss your code and the components of your network.

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch_geometric
from torch_geometric.loader import DataLoader
import torch_geometric.utils as utils
import networkx as nx
from torch.nn import Linear
from torch.nn import BatchNorm2d as BatchNorm
from torch_geometric.nn import global_mean_pool, GraphConv, GATConv, GCNConv, BatchNorm, Global_max_pool

# %config InlineBackend.figure_format = 'svg'

# %%
dataset = torch.load('graph_data_decoding_2023.pt')

# %% [markdown]
# #### Note that the label y, is given by a tensor with 2 elements, giving a binary representation of the predicted equivalence class.
#
# #### *   00 <-> class I
# #### *   10 <-> class X
# #### *   01 <-> class Z
# #### *   11 <-> class Y
#
# #### The loss can either be constructed using two spearate classifiers, one for X and one for Z, or combined into one over all four classes. Either should work.

# %%
# split the dataset into test and validation:
num_samples = len(dataset)
train_data = dataset[int(.95 * num_samples ) :] # 95% train
test_data = dataset[: int(.05 * num_samples )] # 5% test
train_loader = DataLoader(train_data, batch_size=1000, shuffle=True)
test_loader = DataLoader(test_data, batch_size=1000, shuffle=True)

# %%
# GNN Architecture
class GNN(torch.nn.Module):
    '''
    input_features: features of dataset
    output_dim: classes of dataset
    width: How many hidden neurons in each layer
    '''
    def __init__(self,
                 input_features,
                 width, output_dim):
        super().__init__()
        self.conv1 = GCNConv(input_features, 2 * width)
        self.conv2 = GCNConv(2 * width, 2 * width)
        self.conv3 = GCNConv(2 * width, 2 * width)
        self.conv4 = GCNConv(2 * width, 2 * width)
        self.conv5 = GCNConv(2 * width, 2 * width)
        self.dropout1 = Dropout(p=0.5)
        self.lin1 = Linear(2 * width, width)
        self.dropout2 = Dropout(p=0.5)
        self.lin2 = Linear(width, output_dim)

    def forward(self, x, edge_index, batch, edge_attribute):
      x = self.conv1(x, edge_index, edge_weight=edge_attribute)
      x = F.relu(x)
      x = self.conv2(x, edge_index, edge_weight=edge_attribute)
      x = F.relu(x)
      x = self.conv3(x, edge_index, edge_weight=edge_attribute)
      x = F.relu(x)
      x = self.conv4(x, edge_index, edge_weight=edge_attribute)
      x = F.relu(x)
      x = self.conv5(x, edge_index, edge_weight=edge_attribute)
      x = F.relu(x)

      x = global_mean_pool(x, batch)

      x = self.dropout1(x)
      x = self.lin1(x)
      x = F.relu(x)

      x = self.dropout2(x)
      x = self.lin2(x)

      return x

# %%
# Test GNN
class GNN(torch.nn.Module):
    def __init__(self, input_features, hidden_channels, output_dim):
        super().__init__()
        self.heads = 2
        self.conv1 = GCNConv(input_features, hidden_channels)
        self.conv2 = GATConv(hidden_channels, hidden_channels*2, heads=self.heads)
        self.conv3 = GCNConv(hidden_channels*2*self.heads, hidden_channels*2)
        self.conv4 = GraphConv(hidden_channels*2, hidden_channels*2)
        self.lin = torch.nn.Linear(hidden_channels*2, output_dim)

    def forward(self, x, edge_index, batch, edge_attr):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = F.dropout(x, p=0.5, training=self.training)

        x = self.conv2(x, edge_index, edge_attr)
        x = F.relu(x)
        x = F.dropout(x, p=0.5, training=self.training)
        
        x = self.conv3(x, edge_index)
        x = F.relu(x)
        x = F.dropout(x, p=0.5, training=self.training)
        
        x = self.conv4(x, edge_index, edge_attr)
        x = F.relu(x)
        x = F.dropout(x, p=0.5, training=self.training)
        
        x = global_mean_pool(x, batch)
        x = self.lin(x)

        return x

# %%
# Model
input_features = dataset[0].x.size(1)
width = 128
output_dim = dataset[0].y.size(1)
model = GNN(input_features, width, output_dim)
print(model)

# Optimizer
lr = 0.01
weight_decay = 5e-4
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
criterion = torch.nn.CrossEntropyLoss()

def train():
    model.train()

    for data in train_loader:  # Iterate in batches over the training dataset.
         out = model(data.x, data.edge_index, data.batch, data.edge_attr)  # Perform a single forward pass.
         loss = criterion(out, data.y)  # Compute the loss.
         loss.backward()  # Derive gradients.
         optimizer.step()  # Update parameters based on gradients.
         optimizer.zero_grad()  # Clear gradients.

def test(loader):
     model.eval()
     correct = 0
     for data in loader:  # Iterate in batches over the training/test dataset.
         out = model(data.x, data.edge_index, data.batch, data.edge_attr)  
         pred = out.argmax(dim=1)  # Use the class with highest probability.
         correct += int((pred == data.y.argmax(dim=1)).sum())  # Check against ground-truth labels.
     return correct / len(loader.dataset)  # Derive ratio of correct predictions.

train_list = []
test_list = []
for epoch in range(1, 21):
    train()
    train_acc = test(train_loader)
    test_acc = test(test_loader)
    train_list.append(train_acc)
    test_list.append(test_acc)
    print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
# Out:
# GNN(
#   (conv1): GCNConv(4, 128)
#   (conv2): GATConv(128, 256, heads=2)
#   (conv3): GCNConv(512, 256)
#   (conv4): GraphConv(256, 256)
#   (lin): Linear(in_features=256, out_features=2, bias=True)
# )
# Epoch: 001, Train Acc: 0.5850, Test Acc: 0.5845
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[225], line 37
#      35 for epoch in range(1, 21):
#      36     train()
# ---> 37     train_acc = test(train_loader)
#      38     test_acc = test(test_loader)
#      39     train_list.append(train_acc)
#
# Cell In[225], line 28, in test(loader)
#      26 correct = 0
#      27 for data in loader:  # Iterate in batches over the training/test dataset.
# ---> 28     out = model(data.x, data.edge_index, data.batch, data.edge_attr)
#      29     pred = out.argmax(dim=1)  # Use the class with highest probability.
#      30     correct += int((pred == data.y.argmax(dim=1)).sum())  # Check against ground-truth labels.
#
# File ~\Documents\Chalmers\Advanced machine learning with neural networks\Advanced-ML-TIF360\hwa_venv\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[224], line 25, in GNN.forward(self, x, edge_index, batch, edge_attr)
#      22 x = F.relu(x)
#      23 x = F.dropout(x, p=0.5, training=self.training)
# ---> 25 x = self.conv4(x, edge_index, edge_attr)
#      26 x = F.relu(x)
#      27 x = F.dropout(x, p=0.5, training=self.training)
#
# File ~\Documents\Chalmers\Advanced machine learning with neural networks\Advanced-ML-TIF360\hwa_venv\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\Documents\Chalmers\Advanced machine learning with neural networks\Advanced-ML-TIF360\hwa_venv\lib\site-packages\torch_geometric\nn\conv\graph_conv.py:92, in GraphConv.forward(self, x, edge_index, edge_weight, size)
#      90 x_r = x[1]
#      91 if x_r is not None:
# ---> 92     out = out + self.lin_root(x_r)
#      94 return out
#
# File ~\Documents\Chalmers\Advanced machine learning with neural networks\Advanced-ML-TIF360\hwa_venv\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\Documents\Chalmers\Advanced machine learning with neural networks\Advanced-ML-TIF360\hwa_venv\lib\site-packages\torch_geometric\nn\dense\linear.py:132, in Linear.forward(self, x)
#     127 def forward(self, x: Tensor) -> Tensor:
#     128     r"""
#     129     Args:
#     130         x (torch.Tensor): The input features.
#     131     """
# --> 132     return F.linear(x, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
plt.plot(train_list, label='Training accuracy')
plt.plot(test_list, label='Test accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()
